# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import numpy as np

# %%
week_days_path = "./data/paris_weekdays.csv"
week_ends_path = "./data/paris_weekends.csv"

paris_weekdays = pd.read_csv(week_days_path, index_col=0)
paris_weekends = pd.read_csv(week_ends_path, index_col=0)

# %%
# Find the row with the lowest dist in paris_weekdays
lowest_dist_weekdays = paris_weekdays.loc[paris_weekdays['dist'].idxmin()]
print("Weekdays - Row with lowest dist:")
print(lowest_dist_weekdays)
# Out:
# Weekdays - Row with lowest dist:
# realSum                            437.133004
# room_type                     Entire home/apt
# room_shared                             False
# room_private                            False
# person_capacity                           2.0
# host_is_superhost                       False
# multi                                       0
# biz                                         0
# cleanliness_rating                       10.0
# guest_satisfaction_overall               94.0
# bedrooms                                    0
# dist                                 0.071543
# metro_dist                           0.101447
# attr_index                         755.195183
# attr_index_norm                     36.762647
# rest_index                        1233.638325
# rest_index_norm                     72.488017
# lng                                    2.3527
# lat                                  48.85721
# Name: 514, dtype: object

# %%
# Find the row with the lowest dist in paris_weekends
lowest_dist_weekends = paris_weekends.loc[paris_weekends['dist'].idxmin()]
print("\nWeekends - Row with lowest dist:")
print(lowest_dist_weekends)
# Out:
# Weekends - Row with lowest dist:
# realSum                            473.017057
# room_type                     Entire home/apt
# room_shared                             False
# room_private                            False
# person_capacity                           2.0
# host_is_superhost                       False
# multi                                       0
# biz                                         0
# cleanliness_rating                       10.0
# guest_satisfaction_overall               94.0
# bedrooms                                    0
# dist                                 0.071566
# metro_dist                           0.101433
# attr_index                         755.147082
# attr_index_norm                     36.719082
# rest_index                        1233.651718
# rest_index_norm                      56.91123
# lng                                    2.3527
# lat                                  48.85721
# Name: 869, dtype: object

# %%
# Find the row with the lowest dist in paris_weekdays
lowest_dist_weekdays = paris_weekdays.loc[paris_weekdays['person_capacity'].idxmax()]
print("Weekdays - Row with lowest dist:")
print(lowest_dist_weekdays)
# Out:
# Weekdays - Row with lowest dist:
# realSum                            815.779663
# room_type                     Entire home/apt
# room_shared                             False
# room_private                            False
# person_capacity                           6.0
# host_is_superhost                       False
# multi                                       0
# biz                                         1
# cleanliness_rating                       10.0
# guest_satisfaction_overall               88.0
# bedrooms                                    2
# dist                                  1.18861
# metro_dist                           0.148942
# attr_index                         463.634192
# attr_index_norm                     22.569556
# rest_index                         1138.05448
# rest_index_norm                     66.871554
# lng                                   2.35136
# lat                                  48.86722
# Name: 26, dtype: object

# %%
week_days_district_path = "./data/paris_weekdays_district.csv"
week_ends_district_path = "./data/paris_weekends_district.csv"

paris_weekdays_dist = pd.read_csv(week_days_district_path, index_col=0)
paris_weekends_dist = pd.read_csv(week_ends_district_path, index_col=0)

print((paris_weekdays_dist['district'] == 0).sum())
print(paris_weekdays.count())
print((paris_weekends_dist['district'] == 0).sum())
# Out:
# 276
# realSum                       3130
# room_type                     3130
# room_shared                   3130
# room_private                  3130
# person_capacity               3130
# host_is_superhost             3130
# multi                         3130
# biz                           3130
# cleanliness_rating            3130
# guest_satisfaction_overall    3130
# bedrooms                      3130
# dist                          3130
# metro_dist                    3130
# attr_index                    3130
# attr_index_norm               3130
# rest_index                    3130
# rest_index_norm               3130
# lng                           3130
# lat                           3130
# dtype: int64
# 298
